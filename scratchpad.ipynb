# %%
# Imports
import pandas as pd

# %%
#look at IRS data
irs = pd.read_csv("./Data/17zpallagi.csv")

# %%
irs
# Out:
#         STATEFIPS STATE  zipcode  agi_stub        N1     mars1     MARS2  \
# 0               1    AL        0         1  802640.0  474470.0   99850.0
# 1               1    AL        0         2  499070.0  218590.0  137460.0
# 2               1    AL        0         3  268590.0   89780.0  134440.0
# 3               1    AL        0         4  170880.0   32180.0  124070.0
# 4               1    AL        0         5  229870.0   22810.0  196990.0
# ...           ...   ...      ...       ...       ...       ...       ...
# 166532         56    WY    99999         2    3630.0    2040.0    1030.0
# 166533         56    WY    99999         3    2470.0    1020.0    1220.0
# 166534         56    WY    99999         4    1820.0     520.0    1200.0
# 166535         56    WY    99999         5    2480.0     390.0    2020.0
# 166536         56    WY    99999         6     700.0     130.0     600.0
#
#            MARS4       ELF    CPREP  ...  N85300  A85300   N11901    A11901  \
# 0       216600.0  717050.0  44090.0  ...     0.0     0.0  64680.0   53602.0
# 1       129760.0  448190.0  26230.0  ...     0.0     0.0  77660.0  118725.0
# 2        38280.0  241060.0  14160.0  ...     0.0     0.0  67820.0  156752.0
# 3        11660.0  154120.0   7980.0  ...     0.0     0.0  48440.0  141721.0
# 4         5540.0  208380.0  11120.0  ...    50.0    19.0  91100.0  465160.0
# ...          ...       ...      ...  ...     ...     ...      ...       ...
# 166532     440.0    3240.0    160.0  ...     0.0     0.0    550.0     889.0
# 166533     200.0    2230.0    120.0  ...     0.0     0.0    570.0    1258.0
# 166534     100.0    1680.0     80.0  ...     0.0     0.0    440.0    1644.0
# 166535      80.0    2290.0    130.0  ...     0.0     0.0    820.0    4527.0
# 166536       0.0     680.0     60.0  ...   450.0  4298.0    330.0   13882.0
#
#           N11900     A11900    N11902     A11902  N12000   A12000
# 0       700940.0  1803125.0  698100.0  1796343.0  2860.0   4917.0
# 1       419640.0  1175607.0  416180.0  1165352.0  4250.0   8894.0
# 2       201030.0   560461.0  197060.0   547812.0  5440.0  13482.0
# 3       121930.0   396526.0  118460.0   383588.0  3160.0  12369.0
# 4       138250.0   588068.0  130970.0   529001.0  8430.0  55564.0
# ...          ...        ...       ...        ...     ...      ...
# 166532    2960.0     7332.0    2890.0     7127.0    60.0     70.0
# 166533    1810.0     5299.0    1740.0     5020.0    70.0    164.0
# 166534    1300.0     4643.0    1250.0     4069.0    50.0    197.0
# 166535    1570.0     7633.0    1410.0     6069.0   170.0   1189.0
# 166536     320.0    23131.0     140.0     1672.0   190.0  19241.0
#
# [166537 rows x 153 columns]

# %%
eatery = pd.read_csv("./Data/Datafiniti_Vegetarian_and_Vegan_Restaurants.csv")

# %%
eatery
# Out:
#                         id             dateAdded           dateUpdated  \
# 0     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 1     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 2     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 3     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 4     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# ...                    ...                   ...                   ...
# 9995  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9996  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9997  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9998  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9999  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
#
#                  address                                         categories  \
# 0     1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 1     1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 2     1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 3     1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 4     1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# ...                  ...                                                ...
# 9995    1335 W Thomas Rd  Vegetarian / Vegan Restaurant,Restaurant,Medit...
# 9996    1335 W Thomas Rd  Vegetarian / Vegan Restaurant,Restaurant,Medit...
# 9997    1335 W Thomas Rd  Vegetarian / Vegan Restaurant,Restaurant,Medit...
# 9998    1335 W Thomas Rd  Vegetarian / Vegan Restaurant,Restaurant,Medit...
# 9999    1335 W Thomas Rd  Vegetarian / Vegan Restaurant,Restaurant,Medit...
#
#                   primaryCategories     city claimed country  \
# 0     Accommodation & Food Services   Albany     NaN      US
# 1     Accommodation & Food Services   Albany     NaN      US
# 2     Accommodation & Food Services   Albany     NaN      US
# 3     Accommodation & Food Services   Albany     NaN      US
# 4     Accommodation & Food Services   Albany     NaN      US
# ...                             ...      ...     ...     ...
# 9995  Accommodation & Food Services  Phoenix     NaN      US
# 9996  Accommodation & Food Services  Phoenix     NaN      US
# 9997  Accommodation & Food Services  Phoenix     NaN      US
# 9998  Accommodation & Food Services  Phoenix     NaN      US
# 9999  Accommodation & Food Services  Phoenix     NaN      US
#
#                                              cuisines  ...  postalCode  \
# 0                       Thai,Asian/Pacific,Vegetarian  ...       94706
# 1                       Thai,Asian/Pacific,Vegetarian  ...       94706
# 2                       Thai,Asian/Pacific,Vegetarian  ...       94706
# 3                       Thai,Asian/Pacific,Vegetarian  ...       94706
# 4                       Thai,Asian/Pacific,Vegetarian  ...       94706
# ...                                               ...  ...         ...
# 9995  Mediterranean,Vegetarian,Persian,Middle Eastern  ...       85013
# 9996  Mediterranean,Vegetarian,Persian,Middle Eastern  ...       85013
# 9997  Mediterranean,Vegetarian,Persian,Middle Eastern  ...       85013
# 9998  Mediterranean,Vegetarian,Persian,Middle Eastern  ...       85013
# 9999  Mediterranean,Vegetarian,Persian,Middle Eastern  ...       85013
#
#       priceRangeCurrency  priceRangeMin priceRangeMax  province  sic  \
# 0                    NaN            NaN           NaN        CA  NaN
# 1                    NaN            NaN           NaN        CA  NaN
# 2                    NaN            NaN           NaN        CA  NaN
# 3                    NaN            NaN           NaN        CA  NaN
# 4                    NaN            NaN           NaN        CA  NaN
# ...                  ...            ...           ...       ...  ...
# 9995                 USD           40.0          55.0        AZ  NaN
# 9996                 USD           40.0          55.0        AZ  NaN
# 9997                 USD           40.0          55.0        AZ  NaN
# 9998                 USD           40.0          55.0        AZ  NaN
# 9999                 USD           40.0          55.0        AZ  NaN
#
#                                              sourceURLs  twitter  \
# 0     https://foursquare.com/v/potala-organic-cafe/4...      NaN
# 1     https://foursquare.com/v/potala-organic-cafe/4...      NaN
# 2     https://foursquare.com/v/potala-organic-cafe/4...      NaN
# 3     https://foursquare.com/v/potala-organic-cafe/4...      NaN
# 4     https://foursquare.com/v/potala-organic-cafe/4...      NaN
# ...                                                 ...      ...
# 9995  https://foursquare.com/v/persian-garden-cafe/4...      NaN
# 9996  https://foursquare.com/v/persian-garden-cafe/4...      NaN
# 9997  https://foursquare.com/v/persian-garden-cafe/4...      NaN
# 9998  https://foursquare.com/v/persian-garden-cafe/4...      NaN
# 9999  https://foursquare.com/v/persian-garden-cafe/4...      NaN
#
#                                                websites yearOpened
# 0                http://www.potala.us/,http://potala.us        NaN
# 1                http://www.potala.us/,http://potala.us        NaN
# 2                http://www.potala.us/,http://potala.us        NaN
# 3                http://www.potala.us/,http://potala.us        NaN
# 4                http://www.potala.us/,http://potala.us        NaN
# ...                                                 ...        ...
# 9995  http://persiangardencafe.com,http://www.persia...        NaN
# 9996  http://persiangardencafe.com,http://www.persia...        NaN
# 9997  http://persiangardencafe.com,http://www.persia...        NaN
# 9998  http://persiangardencafe.com,http://www.persia...        NaN
# 9999  http://persiangardencafe.com,http://www.persia...        NaN
#
# [10000 rows x 47 columns]

# %%
eatery.province.value_counts()
# Out:
# NY    5361
# CA    1019
# FL     528
# IL     451
# TX     390
# NC     323
# OR     316
# PA     271
# VA     268
# WA     198
# AZ     166
# MA     144
# UT     100
# MI      95
# MN      75
# NM      66
# NH      50
# WI      47
# NJ      42
# KS      28
# HI      26
# TN      17
# ME       8
# NV       6
# GA       5
# Name: province, dtype: int64

# %%
ny_mask =  eatery.province == "NY"
ny = eatery[ny_mask]

# %%
ny
# Out:
#                         id             dateAdded           dateUpdated  \
# 37    AVzHCLzmLD2H7whiWY6R  2017-06-20T19:44:17Z  2018-09-02T10:36:59Z
# 38    AVzHCLzmLD2H7whiWY6R  2017-06-20T19:44:17Z  2018-09-02T10:36:59Z
# 39    AVzHCLzmLD2H7whiWY6R  2017-06-20T19:44:17Z  2018-09-02T10:36:59Z
# 40    AVzHCLzmLD2H7whiWY6R  2017-06-20T19:44:17Z  2018-09-02T10:36:59Z
# 41    AVzHCLzmLD2H7whiWY6R  2017-06-20T19:44:17Z  2018-09-02T10:36:59Z
# ...                    ...                   ...                   ...
# 9847  AV8wVUZERxPSIh2RltJ4  2017-10-18T16:27:36Z  2018-01-30T05:17:58Z
# 9848  AV8wVUZERxPSIh2RltJ4  2017-10-18T16:27:36Z  2018-01-30T05:17:58Z
# 9849  AV8wVUZERxPSIh2RltJ4  2017-10-18T16:27:36Z  2018-01-30T05:17:58Z
# 9850  AV8wVUZERxPSIh2RltJ4  2017-10-18T16:27:36Z  2018-01-30T05:17:58Z
# 9851  AV8wVUZERxPSIh2RltJ4  2017-10-18T16:27:36Z  2018-01-30T05:17:58Z
#
#             address                                         categories  \
# 37    2265 Broadway  Restaurant,Juice Bars,Smoothies and Juices,Veg...
# 38    2265 Broadway  Restaurant,Juice Bars,Smoothies and Juices,Veg...
# 39    2265 Broadway  Restaurant,Juice Bars,Smoothies and Juices,Veg...
# 40    2265 Broadway  Restaurant,Juice Bars,Smoothies and Juices,Veg...
# 41    2265 Broadway  Restaurant,Juice Bars,Smoothies and Juices,Veg...
# ...             ...                                                ...
# 9847  321 W 49th St                       Restaurant,Salads,Vegetarian
# 9848  321 W 49th St                       Restaurant,Salads,Vegetarian
# 9849  321 W 49th St                       Restaurant,Salads,Vegetarian
# 9850  321 W 49th St                       Restaurant,Salads,Vegetarian
# 9851  321 W 49th St                       Restaurant,Salads,Vegetarian
#
#                   primaryCategories      city claimed country  \
# 37    Accommodation & Food Services  New York     NaN      US
# 38    Accommodation & Food Services  New York     NaN      US
# 39    Accommodation & Food Services  New York     NaN      US
# 40    Accommodation & Food Services  New York     NaN      US
# 41    Accommodation & Food Services  New York     NaN      US
# ...                             ...       ...     ...     ...
# 9847  Accommodation & Food Services  New York     NaN      US
# 9848  Accommodation & Food Services  New York     NaN      US
# 9849  Accommodation & Food Services  New York     NaN      US
# 9850  Accommodation & Food Services  New York     NaN      US
# 9851  Accommodation & Food Services  New York     NaN      US
#
#                                      cuisines  ...  postalCode  \
# 37    Smoothies and Juices,Vegetarian,Healthy  ...       10024
# 38    Smoothies and Juices,Vegetarian,Healthy  ...       10024
# 39    Smoothies and Juices,Vegetarian,Healthy  ...       10024
# 40    Smoothies and Juices,Vegetarian,Healthy  ...       10024
# 41    Smoothies and Juices,Vegetarian,Healthy  ...       10024
# ...                                       ...  ...         ...
# 9847                        Salads,Vegetarian  ...       10019
# 9848                        Salads,Vegetarian  ...       10019
# 9849                        Salads,Vegetarian  ...       10019
# 9850                        Salads,Vegetarian  ...       10019
# 9851                        Salads,Vegetarian  ...       10019
#
#       priceRangeCurrency  priceRangeMin priceRangeMax  province  sic  \
# 37                   NaN            NaN           NaN        NY  NaN
# 38                   NaN            NaN           NaN        NY  NaN
# 39                   NaN            NaN           NaN        NY  NaN
# 40                   NaN            NaN           NaN        NY  NaN
# 41                   NaN            NaN           NaN        NY  NaN
# ...                  ...            ...           ...       ...  ...
# 9847                 NaN            NaN           NaN        NY  NaN
# 9848                 NaN            NaN           NaN        NY  NaN
# 9849                 NaN            NaN           NaN        NY  NaN
# 9850                 NaN            NaN           NaN        NY  NaN
# 9851                 NaN            NaN           NaN        NY  NaN
#
#                                              sourceURLs  twitter  \
# 37    https://www.allmenus.com/ny/new-york/476309-gr...      NaN
# 38    https://www.allmenus.com/ny/new-york/476309-gr...      NaN
# 39    https://www.allmenus.com/ny/new-york/476309-gr...      NaN
# 40    https://www.allmenus.com/ny/new-york/476309-gr...      NaN
# 41    https://www.allmenus.com/ny/new-york/476309-gr...      NaN
# ...                                                 ...      ...
# 9847  https://www.allmenus.com/ny/new-york/321208-ju...      NaN
# 9848  https://www.allmenus.com/ny/new-york/321208-ju...      NaN
# 9849  https://www.allmenus.com/ny/new-york/321208-ju...      NaN
# 9850  https://www.allmenus.com/ny/new-york/321208-ju...      NaN
# 9851  https://www.allmenus.com/ny/new-york/321208-ju...      NaN
#
#                                                websites yearOpened
# 37    http://www.greenforcejuice.com,http://greenfor...        NaN
# 38    http://www.greenforcejuice.com,http://greenfor...        NaN
# 39    http://www.greenforcejuice.com,http://greenfor...        NaN
# 40    http://www.greenforcejuice.com,http://greenfor...        NaN
# 41    http://www.greenforcejuice.com,http://greenfor...        NaN
# ...                                                 ...        ...
# 9847                               http://justsalad.com        NaN
# 9848                               http://justsalad.com        NaN
# 9849                               http://justsalad.com        NaN
# 9850                               http://justsalad.com        NaN
# 9851                               http://justsalad.com        NaN
#
# [5361 rows x 47 columns]

# %% [markdown]
# ### To Do
# - Drop columns with to many NaN
# - Decide if I want to look at all States and cities or focus on larger cities
# - Go over resource page for IRS info

# %% [markdown]
# ## Look at Yelp Datasets

# %%
yelp = pd.read_json("./yelp_dataset/yelp_academic_dataset_business.json", lines=True)

# %%
yelp.head()
# Out:
#               business_id                      name  \
# 0  f9NumwFMBDn751xgFiRbNA  The Range At Lake Norman
# 1  Yzvjg0SayhoZgCljUJRF9Q         Carlos Santo, NMD
# 2  XNoUzKckATkOD1hP6vghZg                   Felinus
# 3  6OAZjbxqM5ol29BuHsil3w      Nevada House of Hose
# 4  51M2Kk903DFYI6gnB5I6SQ   USE MY GUY SERVICES LLC
#
#                      address             city state postal_code   latitude  \
# 0            10913 Bailey Rd        Cornelius    NC       28031  35.462724
# 1  8880 E Via Linda, Ste 107       Scottsdale    AZ       85258  33.569404
# 2      3554 Rue Notre-Dame O         Montreal    QC     H4C 1P4  45.479984
# 3             1015 Sharp Cir  North Las Vegas    NV       89030  36.219728
# 4         4827 E Downing Cir             Mesa    AZ       85205  33.428065
#
#     longitude  stars  review_count  is_open  \
# 0  -80.852612    3.5            36        1
# 1 -111.890264    5.0             4        1
# 2  -73.580070    5.0             5        1
# 3 -115.127725    2.5             3        0
# 4 -111.726648    4.5            26        1
#
#                                           attributes  \
# 0  {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 1  {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 2                                               None
# 3  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 4  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
#
#                                           categories  \
# 0  Active Life, Gun/Rifle Ranges, Guns & Ammo, Sh...
# 1  Health & Medical, Fitness & Instruction, Yoga,...
# 2                   Pets, Pet Services, Pet Groomers
# 3  Hardware Stores, Home Services, Building Suppl...
# 4  Home Services, Plumbing, Electricians, Handyma...
#
#                                                hours
# 0  {'Monday': '10:0-18:0', 'Tuesday': '11:0-20:0'...
# 1                                               None
# 2                                               None
# 3  {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...
# 4  {'Monday': '0:0-0:0', 'Tuesday': '9:0-16:0', '...

# %%
yelp.categories.nunique()
# Out:
# 102494

# %% [markdown]
# ## Look at Zomato Dataset

# %%
zomato_csv = pd.read_csv("./food_data/zomato.csv", encoding='ISO-8859-1')

# %%
zomato_csv.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
zomato_csv.shape
# Out:
# (9551, 21)

# %%
zomato_csv.Cuisines.str.contains("Vegetarian")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# Name: Cuisines, Length: 9551, dtype: bool

# %% [markdown]
# ## Income

# %%
irs.head()
# Out:
#    STATEFIPS STATE  zipcode  agi_stub        N1     mars1     MARS2     MARS4  \
# 0          1    AL        0         1  802640.0  474470.0   99850.0  216600.0
# 1          1    AL        0         2  499070.0  218590.0  137460.0  129760.0
# 2          1    AL        0         3  268590.0   89780.0  134440.0   38280.0
# 3          1    AL        0         4  170880.0   32180.0  124070.0   11660.0
# 4          1    AL        0         5  229870.0   22810.0  196990.0    5540.0
#
#         ELF    CPREP  ...  N85300  A85300   N11901    A11901    N11900  \
# 0  717050.0  44090.0  ...     0.0     0.0  64680.0   53602.0  700940.0
# 1  448190.0  26230.0  ...     0.0     0.0  77660.0  118725.0  419640.0
# 2  241060.0  14160.0  ...     0.0     0.0  67820.0  156752.0  201030.0
# 3  154120.0   7980.0  ...     0.0     0.0  48440.0  141721.0  121930.0
# 4  208380.0  11120.0  ...    50.0    19.0  91100.0  465160.0  138250.0
#
#       A11900    N11902     A11902  N12000   A12000
# 0  1803125.0  698100.0  1796343.0  2860.0   4917.0
# 1  1175607.0  416180.0  1165352.0  4250.0   8894.0
# 2   560461.0  197060.0   547812.0  5440.0  13482.0
# 3   396526.0  118460.0   383588.0  3160.0  12369.0
# 4   588068.0  130970.0   529001.0  8430.0  55564.0
#
# [5 rows x 153 columns]

# %%
columns_to_keep = ["STATEFIPS", "STATE", "zipcode", "N1", "A00100", "A02650", "N02650"]

# %%
irs_df = irs[columns_to_keep]

# %%
irs_df
# Out:
#         STATEFIPS STATE  zipcode        N1      A00100      A02650    N02650
# 0               1    AL        0  802640.0  10467448.0  10626881.0  802640.0
# 1               1    AL        0  499070.0  17977581.0  18153235.0  499070.0
# 2               1    AL        0  268590.0  16502473.0  16659518.0  268590.0
# 3               1    AL        0  170880.0  14817087.0  14951547.0  170900.0
# 4               1    AL        0  229870.0  31131390.0  31461757.0  229850.0
# ...           ...   ...      ...       ...         ...         ...       ...
# 166532         56    WY    99999    3630.0    132401.0    133833.0    3630.0
# 166533         56    WY    99999    2470.0    152256.0    153790.0    2470.0
# 166534         56    WY    99999    1820.0    157779.0    159192.0    1820.0
# 166535         56    WY    99999    2480.0    328980.0    333132.0    2480.0
# 166536         56    WY    99999     700.0    459890.0    469004.0     700.0
#
# [166537 rows x 7 columns]

# %%
#need to drop the invalid zipcodes 0 and 99999
not_zip_0_mask = irs_df.zipcode != 0
not_zip_99999_mask = irs_df.zipcode != 99999

# %%
#apply the masks
irs_df = irs_df[not_zip_0_mask]
irs_df = irs_df[not_zip_99999_mask]
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
irs_df.zipcode.value_counts()
# Out:
# 28658    6
# 97541    6
# 75022    6
# 77071    6
# 99610    6
#         ..
# 97531    5
# 64672    5
# 53706    4
# 55455    4
# 52242    4
# Name: zipcode, Length: 27658, dtype: int64

# %%
irs_df[irs_df.zipcode == 28658]
# Out:
#         STATEFIPS STATE  zipcode      N1    A00100    A02650  N02650
# 108668         37    NC    28658  4600.0   57768.0   58415.0  4600.0
# 108669         37    NC    28658  3520.0  125846.0  126896.0  3520.0
# 108670         37    NC    28658  1710.0  104241.0  105159.0  1710.0
# 108671         37    NC    28658   900.0   77754.0   78414.0   900.0
# 108672         37    NC    28658   950.0  123958.0  125164.0   950.0
# 108673         37    NC    28658   220.0  105189.0  106962.0   220.0

# %%
grouped_N1_zip = irs_df.groupby(irs_df.zipcode).N1.sum().reset_index()
grouped_N1_zip
# Out:
#        zipcode      N1
# 0         1001  9060.0
# 1         1002  9530.0
# 2         1005  2400.0
# 3         1007  7630.0
# 4         1008   650.0
# ...        ...     ...
# 27653    99824  1150.0
# 27654    99827  1280.0
# 27655    99833  1710.0
# 27656    99835  4450.0
# 27657    99901  6340.0
#
# [27658 rows x 2 columns]

# %%
grouped_A00100_zip = irs_df.groupby(irs_df.zipcode).A00100.sum().reset_index()
grouped_A00100_zip
# Out:
#        zipcode    A00100
# 0         1001  529890.0
# 1         1002  854749.0
# 2         1005  142207.0
# 3         1007  565653.0
# 4         1008   42714.0
# ...        ...       ...
# 27653    99824   86288.0
# 27654    99827   77584.0
# 27655    99833  116268.0
# 27656    99835  315589.0
# 27657    99901  415667.0
#
# [27658 rows x 2 columns]

# %%
grouped_A02650_zip = irs_df.groupby(irs_df.zipcode).A02650.sum().reset_index()

# %%
grouped_N02650_zip = irs_df.groupby(irs_df.zipcode).N02650.sum().reset_index()

# %%
#merge dataframes df.join(people.set_index("FIPS"), on="FIPS")
df1 = grouped_N1_zip.join(grouped_A00100_zip.set_index("zipcode"), on="zipcode")

# %%
df1
# Out:
#        zipcode      N1    A00100
# 0         1001  9060.0  529890.0
# 1         1002  9530.0  854749.0
# 2         1005  2400.0  142207.0
# 3         1007  7630.0  565653.0
# 4         1008   650.0   42714.0
# ...        ...     ...       ...
# 27653    99824  1150.0   86288.0
# 27654    99827  1280.0   77584.0
# 27655    99833  1710.0  116268.0
# 27656    99835  4450.0  315589.0
# 27657    99901  6340.0  415667.0
#
# [27658 rows x 3 columns]

# %%
df2 = df1.join(grouped_A02650_zip.set_index("zipcode"), on="zipcode")
df2
# Out:
#        zipcode      N1    A00100    A02650
# 0         1001  9060.0  529890.0  535877.0
# 1         1002  9530.0  854749.0  872920.0
# 2         1005  2400.0  142207.0  143893.0
# 3         1007  7630.0  565653.0  573583.0
# 4         1008   650.0   42714.0   43167.0
# ...        ...     ...       ...       ...
# 27653    99824  1150.0   86288.0   87361.0
# 27654    99827  1280.0   77584.0   79487.0
# 27655    99833  1710.0  116268.0  120822.0
# 27656    99835  4450.0  315589.0  324784.0
# 27657    99901  6340.0  415667.0  423083.0
#
# [27658 rows x 4 columns]

# %%
df3 = df2.join(grouped_N02650_zip.set_index("zipcode"), on="zipcode")

# %%
df3
# Out:
#        zipcode      N1    A00100    A02650  N02650
# 0         1001  9060.0  529890.0  535877.0  9060.0
# 1         1002  9530.0  854749.0  872920.0  9530.0
# 2         1005  2400.0  142207.0  143893.0  2400.0
# 3         1007  7630.0  565653.0  573583.0  7630.0
# 4         1008   650.0   42714.0   43167.0   650.0
# ...        ...     ...       ...       ...     ...
# 27653    99824  1150.0   86288.0   87361.0  1150.0
# 27654    99827  1280.0   77584.0   79487.0  1280.0
# 27655    99833  1710.0  116268.0  120822.0  1710.0
# 27656    99835  4450.0  315589.0  324784.0  4450.0
# 27657    99901  6340.0  415667.0  423083.0  6340.0
#
# [27658 rows x 5 columns]

# %%
cols_to_keep = ["STATEFIPS", "STATE", "zipcode"]

# %%
state_zips = irs_df[cols_to_keep]

# %%
state_zips
# Out:
#         STATEFIPS STATE  zipcode
# 6               1    AL    35004
# 7               1    AL    35004
# 8               1    AL    35004
# 9               1    AL    35004
# 10              1    AL    35004
# ...           ...   ...      ...
# 166526         56    WY    83414
# 166527         56    WY    83414
# 166528         56    WY    83414
# 166529         56    WY    83414
# 166530         56    WY    83414
#
# [165925 rows x 3 columns]
